# %%
# Importing required libraries
import string
import numpy as np
import pandas as pd
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords, wordnet
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Loading training and testing data
train = pd.read_csv('./training_data.csv')
test = pd.read_csv('./test_data.csv')

# %% [markdown]
# # Data Preprocessing

# %%
train.head()
# Out:
#              tweet_id airline_sentiment  ...              tweet_location               user_timezone
# 0  567900433542488064          negative  ...             Washington D.C.      Atlantic Time (Canada)
# 1  569989168903819264          positive  ...  Indianapolis, Indiana; USA  Central Time (US & Canada)
# 2  568089179520954368          positive  ...                    Illinois  Central Time (US & Canada)
# 3  568928195581513728          negative  ...                         NaN      Atlantic Time (Canada)
# 4  568594180014014464          negative  ...                         NaN  Eastern Time (US & Canada)
#
# [5 rows x 12 columns]

# %%
train.isnull().sum()
# Out:
# tweet_id                      0
# airline_sentiment             0
# airline                       0
# airline_sentiment_gold    10949
# name                          0
# negativereason_gold       10956
# retweet_count                 0
# text                          0
# tweet_coord               10204
# tweet_created                 0
# tweet_location             3550
# user_timezone              3577
# dtype: int64

# %%
train_data = np.array(train['text'])
train_output = np.array(train['airline_sentiment'])
test_data = np.array(test['text'])

# %%
# Using Lemmatizer to group togetger forms of inflected forms
lemmatizer = WordNetLemmatizer()

# %%
# To remove Airline names from tweets
not_reqd = set(train['airline'])
not_reqd
# Out:
# {'American', 'Delta', 'Southwest', 'US Airways', 'United', 'Virgin America'}

# %%
# Importing stopwords using nltk and adding punctuations as well as few more words
stops = set(stopwords.words("english"))
punctuations = string.punctuation
stops = list(stops) + list(punctuations) + list(not_reqd) + ['@','http','americanair', 'JetBlue','SouthwestAir', 'USAirways']

# %%
# Function to return POS in the format required by lemmatizer
def simple_pos(word):
    if word.startswith('J'):
        return wordnet.ADJ
    if word.startswith("V"):
        return wordnet.VERB
    if word.startswith("R"):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Function to remove stops(stopwords) from the tweets
def clean_word(words):
    output_words = []
    for w in words:
        if (w.lower() not in stops) and (w.isnumeric() == False):
            pos = pos_tag(w)
            clean_word = lemmatizer.lemmatize(w, pos = simple_pos(pos[0][1]))
            output_words.append(clean_word)
    return output_words

# %%
# Joining the words in sentence after cleaning the words
train = [' '.join(clean_word(word_tokenize(word))) for word in train_data]

# %%
train
# Out:
# ['SouthwestAir scheduled morning days fact yes..not sure evening flight one Cancelled Flightled',
#  'SouthwestAir seeing worker time time going beyond love flying guy Thank',
#  'united Flew ORD Miami back great crew service leg THANKS',
#  "SouthwestAir dultch97 's horse radish 😤🐴",
#  'united flight ORD delayed Air Force One last flight SBN 8:20 min landed',
#  'united load us flying sardine knew pilot hour Late Flight incompetent beyond belief',
#  "JetBlue stock response Delays frustrating poor cust serv amp told ppl wait amp 'd come back",
#  "JetBlue 'd nice Hoping rack enough mile take trip Seattle enjoy perfect latte city coffee",
#  'united frankly worse customer service ever Problems happen deal defines company Never United',
#  "SouthwestAir yeah haha Never one 's expensive 😂😂 much fun destinationdragons",
#  "SouthwestAir MCO- gt DCA flight almost full people screwed MSY-DCA Cancelled Flightation united USAirways n't Cancelled Flight SWA=mistake",
#  "JetBlue 's easiest way get ticket receipt get one check get one online Thanks",
#  'USAirways love change lounge cheese veggie olive addition cracker snack mix',
#  'SouthwestAir receive bad customer service ended spending several hundred dollar accommodate family cxl flight',
#  "USAirways 're killing sche flight board min mine arrived gate side airport genious",
#  "USAirways week refund ticket totally unacceptable Fix 'll put blast social medium TV",
#  'private msg provide detail ... u really need customer svc training staff',
#  "RT JetBlue fleet 's fleek //t.co/413GiAL0yl",
#  'JetBlue info flight SJU JFK already delayed 1/2 hour',
#  "'ve tried le time today get touch service desk beginning 8:30 EST 'm luck -help",
#  "USAirways new problem ... wrong last name reservation airway fixed New ca n't get TSA",
#  'SouthwestAir possible chance SWA bringing back service LGA-BWI would make much easier connect west coast',
#  'USAirways run show airport boarding pass say us airway wait American line yousuck',
#  "united computer stopped giving updates took flight info app 's ridiculous keep people updated",
#  'united good fly United businessFirst',
#  'united flying msp dxb child turn trip buy return ticket child',
#  'JetBlue love Cancelled Flightling ticket telling customer flyunited',
#  'united ORD waited min crew member left gate item come Flight attendant sarcastically say good luck walk away',
#  'SouthwestAir Jason Gate SAN make afternoon southwestairlines stellarservice thanks',
#  'everything sorted Thanks help Excited get home tonight',
#  'understand weather would nice hear apology phone moved flight inconvenient day',
#  'SouthwestAir thanks',
#  "united 's booked first class curbside delivery hour 'm counting TeamUSA",
#  "JetBlue Oh totally look par 's Admirals Club way slide us couple pass",
#  "'ve official complaint signed AmericanAirlines Lima supervisor Customer Relations pls compensate 10-hour delay",
#  "JetBlue hour policy- call say n't report soon enough would changed noticed sooner",
#  "united frustrating flying experience One continuous `` dunno time leave today `` Dunno 's code ...",
#  "SouthwestAir Hi got message part flights Cancelled Flightled ca n't rebook online nobody answer phone call Help",
#  'SouthwestAir need updates flights amp hold hour',
#  "USAirways 'm supposed fly Dallas help get new itinerary",
#  'fail flight rdu sitting waiting flight attendant logistics good',
#  'united impressed super-fast reply CGJase',
#  "united n't Spoke baggage contact 1-800 number Said try get bag stay IAD pick tmrw",
#  'USAirways intentionally buy flight hour layover kind airline would charge fix Wow ... usairways',
#  "SouthwestAir auto callbacks n't wait hold",
#  'united get service desk IAD',
#  "JetBlue blue helped bring color eye promise n't eat free snack",
#  'united Yes therealaviation Instagram',
#  "JetBlue report updated info n't know reach without super long wait hold main number",
#  "JetBlue want enter family pooling contest say `` 2/19 '' website please enter still",
#  'USAirways choose seat free clicking button',
#  'united plus food taxis',
#  'USAirways 3hr30min right ... end sight',
#  "SouthwestAir 're really going let delta virginamerica get best //t.co/vUdWJm1lYB",
#  'USAirways claim flight Cancelled Flighted due weather destination Delta Cancelled Flighted flight route',
#  'JetBlue thanks much help Us u r amazing',
#  "haha say n't fault somehow guy r joke",
#  "customer service inferior nationalized third world nation 's airline Get together",
#  'iPhone app sort notifications option',
#  'united thank',
#  "'ve trying reach customer service TWO days received zero response Never traveling AA",
#  "united flight agent wander Pilots come looking Went charge personal phone 'd txting",
#  'united first lost bag Cancelled Flight flight home min wait talk somebody poorservice notgoodenough',
#  'SouthwestAir sit plane 2+ hr 2/15 finally took off..',
#  'JetBlue ANYWHERE //t.co/FeFHPmFPlE',
#  'USAirways spend cost flight get free room transportation airport',
#  'SouthwestAir understand weather kid need get home Nice kid volunteer work RI high school please help',
#  "friend needs help flt 's Twiiter DM info",
#  'mom ’ flight tomorrow Cancelled Flighted w/ notice Phone system say callback hour ’ need go bed',
#  'flight veers icy runway dfwairport DFW flights Cancelled Flighted Mon //t.co/Q37pOWn6uv Cowboycerrone figure right',
#  'united Could tell bag would accepted personal item bring one carry-on bag plus //t.co/U390cZpLHl',
#  'united yo need new website really badly day age ...',
#  'SouthwestAir TheEllenShow Imaginedragons kdepetro313 .what great first night DestinationDragons //t.co/N3LrFo4UaY',
#  'USAirways right amp away ✈️🌞',
#  'united two dozen back line see single CSR reFlight Booking Problems final leg Kiosks fritz',
#  'JetBlue would charge money transfer point someone',
#  'USAirways possible earn Dividend Miles passenger even purchasing ticket',
#  "Lmfaooo “ JetBlue fleet 's fleek //t.co/1G9RnmYUQe ”",
#  "USAirways phone line call n't affected `` bad weather '' Trying book vacation ... 👀",
#  'never seen incompetency gate agent year business travel DFW B16 gate agent needs training new job',
#  'USAirways F623 DEN PHX impressive lack concern 1hr+ Late Flight flight attndt wrecking havoc customer travel smugsmirk norush',
#  'united clients hr layover IAH day claim amp recheck luggage take care',
#  'united even change could make online- instructed call agent- maybe syastem allow agent link passengers',
#  "united ca n't claim `` weather '' hardworking crew pulling seat plane right thing know wo n't",
#  "finally call Ca n't get met Seattle refund processed Thanks",
#  "United played bizarre `` safety '' video 've ever seen ... //t.co/Hlm2Oks6xl",
#  "SouthwestAir 'm sure messaging part right Please let know received",
#  'SouthwestAir booked 8th ... Save emergency exit ... Got ta stretch',
#  'SouthwestAir try get customer destination help get another airline flights days',
#  'JetBlue catch name sure Jason know',
#  'USAirways Yet another delay/missed connection ... .and customer service attitude Wow',
#  'USAirways access Dividend Miles week automated phone keep telling call back Late Flightr FRUSTRATED LivePersonPlease',
#  'united direct flights Belfast Intl Newark resume winter break Thanks',
#  "united LGJW7B voluntarily rerouted 1st leg journey economy supposed 8B Res agent say 'd reserve",
#  'SouthwestAir Nashville airport runway open appears southwest airline Cancelled Flighting flights likely change',
#  'USAirways flight plan delayed tuesday due computer crash',
#  'SouthwestAir unbelievable ... Thank much DestinationDragons',
#  'united big surprise nogate waiting plane fucken issue everything fly fail worstairlineever',
#  'USAirways tough night two minute call hold delayed Phoenix two days one aircraft ready acceptable',
#  "united 's hard stay upset someone least TRY show remorse",
#  'united min hold trying book award flight site error Agents ask pin see platinum availability badbadbad',
#  'USAirways min hold ... Drove 2.5 hour get delayed bag want pick SJU',
#  'USAirways reserve seat AA flight transfer ORD EVV',
#  'United start 3xdaily EmbraerSA ERJ145 flights Chicago fly2ohare Evansville 4JUN avgeek',
#  'united flight Chicago Houston hour pretzel peanut Seriously pass',
#  'united left comment customer care Thanks contacting',
#  'united held plane Made',
#  "'s ok ... may keep lose bag info longer trust Bad way handle",
#  'VirginAmerica thestarter 😁',
#  'JetBlue Learning awesome twitter management today Social Media Marketing class keep good work SXU PhD_Mama_',
#  'dropping ball cater Plane switch gate attendant hour Late Flight Really nice',
#  'good care customer anything happen take Delta getting back NYC Screw',
#  "n't think help base behavior voucher cot seem like enough lol 😃",
#  "united think problem resolution decided end Especially 'd like continue flying airline",
#  "USAirways 've hold min counting cause charged credit card bag provided receipt say error Awful",
#  'united great Looking forward response DM',
#  "united 's 21st birthday sister coming celebrate flights keep Cancelled Flighting PLZ get",
#  'USAirways UR employee named VAN ticket counter Philadelphia EXTREMELY RUDE Father trying get home sick kid missed flight',
#  'SouthwestAir Horrible experience ever airline..Have reconsider future flights Customer service ... //t.co/EczHcmM5vi',
#  'tomorrow site show flight ewr Cancelled Flightled',
#  'VirginAmerica like customer service min delay connecting passengers seems long VA370',
#  "VirginAmerica cutest salt pepper shaker ever think guy ca n't get better //t.co/vC6Keulg2J",
#  'Unbelievable even wait hold speak human resolve issue system simply hang',
#  "continues win 've never missed flight nice little quiet gate change make possible Sheesh",
#  "USAirways even offered fly another airport say could n't explanation ca n't",
#  "USAirways phone number gate give n't work either customer service phone number",
#  'JetBlue flight Savannah GA',
#  'yes still human hope dealing horror story people share ... complained DOT Everyone',
#  'JetBlue sent plane anyone JetBlue clue',
#  'SouthwestAir winner Imaginedragons DestinationDragons',
#  'united quick serious question resources/ratings showing quality service better 8th place //t.co/deWIthPeW2',
#  "united get first flight day ground time Let 's go ... ...",
#  '“ SouthwestAir Southwest mobile boarding pass available iOS Passbook //t.co/xmRvR4lGEg //t.co/wJoc9f14SU ” tori_leggieri',
#  "SouthwestAir 'm stuck Fort Lauderdale",
#  'JetBlue clear folder regularly JetBlue white listed never got',
#  'united Keep flights cheap early/on time good Flew Cancelled Flightled flight time last month United gt',
#  "JetBlue believe 's Irina flip-side super disappointed EatUp Cafe n't available BOS -- gt SFO flight today",
#  "USAirways 's flight placed original flight Charlotte Cancelled Flightled 1hr delay",
#  "USAirways captain turned seat belt sign people get walk around 's good",
#  'United //t.co/5hpSqVRjK8 flight gone got plane BusinessTravel goodenoughmother',
#  'Call Chairman call Emerald today call former customer',
#  'JetBlue saw one useless tsa agent inspected shoe',
#  'united Thank response',
#  'one received text alert automated call anything either Literally information happen',
#  "USAirways make Send Bloody Mary 's row",
#  'united gate change two delay Even crew think airline suck',
#  'USAirways Thank empathy story luggage thank reaching',
#  "JetBlue Thanks JB Actually birder love need outside n't hard trap move",
#  'USAirways flt CLT DAY supposed depart 5:51 6:20 ... still crew schedule/contact pilot',
#  'JetBlue allow payment Apple Pay Patriarc //t.co/bdUaUZFhW2',
#  "united rep hung min hold asked supervisor 'm furious right",
#  "'re 're trying book PAST need arrive 're still selling seat day 'm trying travel",
#  'USAirways seriously service issue right decide tweet Unbelievable',
#  'also pass website around passengers',
#  'united clicked link got confused //t.co/xMAQcucWZl',
#  'well cleared custom AUH need get IAH arrive DFW possible retrieve luggage IAD',
#  'SouthwestAir TaylorLumsden Taylor U got ta love SWA responsiveness least huh',
#  "flights Cancelled Flightled ca n't get desk nothing showing online reservation",
#  "USAirways 'm pregnant twin 're going abandon overnight airport hotel 's fault",
#  'united thanks prompt response Another hour enjoy vacation Perhaps bug app still show 2:55',
#  'united tried figure go get',
#  'united except delayed flight anyway',
#  'JetBlue get flight air',
#  'united let assure travel time 4h2m 5h2m timezones accuratetraveltimes 3rdtimethishashappened //t.co/e0C9bI09cf',
#  'united thanks catch conection',
#  "“ JetBlue fleet 's fleek //t.co/aJM3BhJVaa ” foh",
#  'VirginAmerica flight artisanal cheese wine pairing',
#  'united flight UA3364 sitting tarmac min report ... input',
#  'USAirways sits throne lie',
#  'SouthwestAir flights Cancelled Flightled today hold hour',
#  "SouthwestAir Late Flightly 've always Late Flight Please get back old SWA",
#  'ex-boyfriend pick call Cancelled Flightedflight nocustomerservice americanairlines FAIL',
#  'SouthwestAir WOULD ANYTHING ticket VEGAS ... ANYTHING love imagine dragon much',
#  "SouthwestAir thanks attention 've flying southwest year n't issue past",
#  "USAirways never let 's every Single Flight Gets delayed",
#  "USAirways wife flying atlanta vega March 7th since could n't get tricities Tn",
#  'united Flight UA1665 got delayed hour due mechanical issue ... could use free drink make inconvenience',
#  'VirginAmerica DREAM //t.co/oA2dRfAoQ2 //t.co/lWWdAc2kHx',
#  "SouthwestAir 'm line airport right cover hotel fair sleep airport",
#  "JetBlue n't know- one would tell coming would guess 's change flights",
#  "worry 're swamped know dmd back THANK U",
#  'SouthwestAir forgot put tsa pre number checked profile boarding pass',
#  'SouthwestAir five people shown yet',
#  "'ve never anything bad say love faithful customer",
#  'SouthwestAir Hello..are flights take DallasLoveField airport noon supposed travel flight San antonio',
#  'SouthwestAir love appreciate fact guy rarely Cancelled Flight flights time need Cancelled Flightlation time 🙏',
#  'Connection US2065',
#  "united good man n't fault plane maintenance issue",
#  "'m sensitive fact n't believe warrant poor service little help amp compassion go long way",
#  "jetblue online resource say 're time clearly information age ...",
#  'united make hard fly Delayed hour plane turning around amp heading back gate connection',
#  'USAirways people kind hardworking infrastructure given horrid massivefail failphone fail',
#  "JetBlue THANKS 80th bday Saturday 're aviation themed surprise party",
#  "JetBlue Airways Reveals 'Bluemanity Livery TravelPulse //t.co/fTTfyFMvCO",
#  'USAirways JosephTReis Dont bother dont pick phone Worst customer service going',
#  'expecting delay DFW tomorrow morning',
#  "USAirways flight leaving 2:45 n't even begun board yet Please update website ASAP",
#  "incredibly arrogant thing say sit O'Hare waiting incompetent airline refuel ...",
#  'JetBlue Airline trouble winter amp getting good customer service contact //t.co/aQjn4HwNaC negotiate resolution',
#  'united thankful great service Newark Seats fixed seated daughter Fab landing Fort Myers',
#  'united feeling like true united customer stuck.on tarmac dc hr UNITEDFAIL',
#  "united cool customer told n't care either expected",
#  "SouthwestAir today 's scavenger hunt start 'm trying help little brother win DestinationDragons",
#  'united lt lt lt lt lt -- -- -- shoddy customer service use whatsoever unitedairline',
#  'JetBlue option luggage assistance ground HPN Flight delayed 2+ hour amp sleeping kid land',
#  "SouthwestAir DM 'd",
#  'united yep—used twice case id numbers assigned tried again-get screen say “ thank submitting request ”',
#  'guy amazing job today Know ’ hard thanks Kate Appleton hard work reFlight Booking Problems friends',
#  'really need customer service training unhappy EEs morning Chicago Gate K20 chking schd',
#  'SouthwestAir employee great',
#  "SouljaCoy AA going fix utterly embarrassing customer service wo n't even answer dang phone",
#  'SouthwestAir Please bring back RDU FLL direct route noticed missing starting Late Flight August flights always pack',
#  "USAirways n't want get home",
#  'USAirways phone line disconnect queue answered phone line simply disconnect call',
#  "JetBlue 'm sitting plane many predictable mechanical problem Still onboard getting bad ...",
#  'USAirways shivadelrahim upgrades',
#  'USAirways never received horrible service treated poorly Richard P. today excuse attitude amp ripping ticket',
#  'JetBlue get copy last flight showing original time delay need work Thanks',
#  'JetBlue get honest update departure flite plane infant children',
#  'USAirways US Wait gate opened Back go Good maybe get',
#  'maintenance MD80 sits two days Frozen line found boarded Come faail mci',
#  "SouthwestAir seriously WORST n't remember last time someone knew flight n't delayed Cancelled Flightled etc",
#  "united wont transfer flight ticket accompany yr old 's active military mom emergency brain surgery WOW",
#  'USAirways ticket counter people helping want charge money even horrible day',
#  'united seg flt yvr zurich would credit mile segs full fare',
#  "need know n't done like promised would yesterday",
#  "JetBlue kudos 're done heading warmer weather",
#  "SouthwestAir yall trying fly Chicago n't live Send home Bullshit as customer service",
#  "SouthwestAir stay Chicago overnight meet bag hope stay put n't get put flight",
#  'united severely staffed Iah',
#  'fantastic thanks try tweet photo view',
#  'SouthwestAir love Companion Pass qualified 4th year HollyMais',
#  'say AA provide in-flight wifi route China base federal law United',
#  'SouthwestAir boarding pass compatible iPhone Passbook //t.co/1ESmMnIZEk',
#  'USAirways disaster Flight missed passenger count since done manually Really',
#  'JetBlue u suck Big Donkey Balls',
#  'SouthwestAir Thanks Confirmation number DMed Appreciate help',
#  "JetBlue n't make feel like criminal want sit near year old flight jetblue //t.co/qgtCao1J2U",
#  "'ve already make arrangement",
#  'USAirways add frequent fly number website help',
#  'SouthwestAir ticket booked 1/27 CUN arrival time reflect CUN EST time',
#  'united lot unhappy cold people bridge freezing temp hour given info',
#  "jetblue 'd love help Shanese Bryant-Melton hard-working grandmother DC go Miami 's bucket list flyitforward",
#  'united Want book multi-city fare mile 1of flights option pay 1st flight mile +2nd UMP Visa Thanks',
#  "united email address/username sign-on available 's",
#  "united yes 've waiting four hour one able help",
#  "thank ca n't get flight hold Cancelled Flights",
#  'USAirways flight scheduled 730pm ... told 150am flight Cancelled Flightled sitting cold plane hour',
#  'united Yes PLENTY seat available Vicky Thomas refuse give one million mile fly',
#  'united UA63 Madrid arrived agent mass confusion sent fro UA employee MaryJo rude unhelpful',
#  'USAirways terminal E Miami still worst smelly airport ever Thanks nothing',
#  "united great decision making skills flight ops IAH bag make minute connection n't flight pushed early Disappointed",
#  'JetBlue checked yesterday looked like something change',
#  'united weighed 45.5 checked bag',
#  'USAirways check online state status closed mean yet able reach live person ...',
#  'united asked DM ignore Please assist changing another flight today- Feb fra mco avoiding IAD',
#  'AmericanAirlines approach mex ... //t.co/se57dmjHiW',
#  'united amp finally told couldnt use front plane restrm row7 though myself/others row behind used w/no issue',
#  "earlier flights SAP- gt Mia amp Mia gt New York lga 03.03 'm currently booked flights",
#  'united last night waited forever gate someone corporate dispatch FORGOT call crew unfriendlyskies',
#  "united SERIOUSLY 's WiFi 5hr flight CLE-SFO 're airline without WiFi ...",
#  'united told changed flight im ottawa airport AC cant find reservation Whats wrong',
#  "“ JetBlue Analystdoc Unfortunately 's available option current system Sorry guy 's certain fail Fix plz",
#  "united n't need apology need bag Took minute landing get Unacceptable",
#  'See photo B787 scale model amp PN 320008A wheel deflator specified Chapter B787 AMM //t.co/kfD4WQRkLW',
#  'united flying STL Saturday expecting ice amp snow start looking travel waiver Thanks',
#  'thanks getting back find airline future',
#  'VirginAmerica know Need spotify stat guiltypleasures',
#  'united patient luxurious middle seat next delayed flight',
#  "USAirways hour tarmac Charleston still ca n't get response week Unacceptable",
#  "SouthwestAir 's happen customer service Cancelled Flightled flights days amp uninformed unapologetic staff nolove cali",
#  'united SFO HNL ZERO entertainment system youareonyourown',
#  'overweight pull dozen passengers luggage Seriously',
#  'JetBlue disappointed flight back boston PR Cancelled Flightled rebooked next day delayed one compensation',
#  'united better customer service John Wayne airport',
#  "waiting delayed plane sit plane hour waiting Late Flight passenger 's BS too..",
#  'united always Helps communicate customer',
#  "united 're customer service unbelievably bad Abysmal 've phone well 2hrs tonight Hung yr ppl 3x",
#  'SouthwestAir 3rd time flying southwest two year another trip back mx October',
#  'Priority baggage evidently mean come last',
#  "united mention one bag infant car seat amp 've stuck yr poor replacement icy mtn road",
#  'united thanks checking',
#  "understand 'm even put hold say `` try Late Flightr goodbye ''",
#  "united wo n't check carry Watched handler throw bag -- miss conveyer belt -- sit min //t.co/lyoocx5mSH",
#  "SouthwestAir rerouted bf 's flight 's diabetic little insulin even though tried change agent would n't",
#  "'s lot talk MIA-SFO 20+ year old plane nonewplanes old shame //t.co/TwETPXUpPN",
#  "flight dca need change asap help ca n't get",
#  'united change Way stick Premiere 1K loyal customer make thing harder loyal',
#  "USAirways ok ... know door close ~10 minute takeoff stop telling flight leave minute n't boarded",
#  'united hope see issue return flight tomorrow',
#  'united customer service 👎',
#  'USAirways wife sick 3yr-old-twins waiting line 2hrs see agent Phone agent say nothing til Tuesday',
#  'JetBlue ruining vacation left right would thought airline Cancelled Flight ticket without telling buyer',
#  "SouthwestAir Guys 've got something inability check online international flight ... 1/2",
#  'USAirways Seriously flight delay Cinci Philly due new ground staff miss connection MAN UK argue hotel WTF',
#  'united line Denver rebook due weather issue BETTER //t.co/tmccExYaaQ',
#  'USAirways redeem pass admiral club free visit barclay card membership bring companion',
#  'USAirways FAILINGYOURCUSTOMER ONE ONE',
#  'JetBlue guy continue impress crew MCO gate 4helped family seat issue professional',
#  "SouthwestAir n't charge ticket change fees incur mysterious `` cost '' incur united",
#  'take call need change flight',
#  'USAirways flight sitting fully loaded hour Air conditioning barely working',
#  'JetBlue dropping passengers small baby infant San Juan terminal unloading baby officer writes ticket',
#  'SouthwestAir continue amazed amazing customer service Thank SWA',
#  'SouthwestAir hilarious flight attendant Vegas Detroit tonight //t.co/nw7vx7DGMF',
#  'people cruel stupid posting personal email damn Internet u lost mind',
#  'narrowly make standby ... lot snag trip',
#  'SouthwestAir Thank thankful feelingtheluv',
#  'Took flight yesterday fron TPA-DFW-AUS Bag went IAH Today bag went IAH-DFW back IAH Still bag',
#  'one agent helping stagnant line almost customer Super',
#  "SouthwestAir pair ticket Imaginedragons show Atlanta 'd love go DestinationDragons",
#  "SouthwestAir got `` duped '' w/ connection 1st flight sneaky u wo n't give seat earlier flight w/ availability Shameful",
#  'SouthwestAir really gon na hear mouth bag situation',
#  "virginamerica phone number ca n't find call flight reservation",
#  'USAirways Thanks would better gate agent C14 Charlotte boarding flight',
#  'JetBlue always pleasure ☺️',
#  'USAirways USAirways disappoints Cancelled Flighted flights Missed appointment Promised refund lie',
#  "united ca n't get anyone deal person Cowardly customer service ca n't looked eye anyone",
#  "something wrong website matter flight select say 's longer available",
#  'SouthwestAir multiple attempt finally able submit Late Flight last night',
#  "SouthwestAir broke stroller wife baby gate checked told 's problem Calling List Preferred line",
#  'JetBlue unfortunately hoping catch one sometime near future',
#  "JetBlue mean take time write physical letter fraud department n't email telephone Right",
#  'Trip cut hr short due flight change/massive layovers/ peanut crackers/ asked H2O received 2oz',
#  'united please follow Dm missing bag',
#  "USAirways please secure 'footrest shelf business class A330 airplane //t.co/ZL4bVEXmcJ",
#  'maryella_green received actually Thank',
#  'JetBlue Amagrino cover cost car service waiting time',
#  "'ve Cancelled Flightled flight First priority ticket bumped 're losing customer People furious",
#  "connect person without wait 2+ hour hold still n't able resolve problem",
#  "USAirways 're reservation numbers none Hungary phone working make difficult",
#  'SouthwestAir checked right 24hr mark Boarding C group kid age amp dnt want split sld',
#  "JetBlue 'm flight booze served min ... give lostrevenue angryandsober bachelorpartymishap",
#  "sweetmel weather bad would n't folks try extra hard communicate ... load bag onto flight ... ... anything",
#  '4369. flights using gate w/buses plane Awful boarding process Hour half Late Flight',
#  'united staff rather efficient got us solution freaked little limbo air',
#  "united flight vega houston Cancelled Flighted morning `` due operation '' mean Thank god woke early today",
#  'USAirways PHL take hour offload bag especially take 30+ min get jetway get plane landing',
#  "'d like apologize gate agent flight AA76 aware zone nine precious gem",
#  '4hrs Late Flightr get call back immediately disconnected',
#  "USAirways wo n't waive fee due neptune Ca n't use credit w/o pay fee Couldnt get destination use tic waivethefee",
#  'insulting USAirways offer `` non required voucher goodwill offering..At least bag fly round trip',
#  "USAirways ca n't even use return flight home change fees charge expensive forcing purchase new ticket",
#  "united 'm rebooked line people deep",
#  'USAirways cust serv rep unable change reservation system Check unaware Cancelled Flights got word night',
#  "united give service terrible n't forced use United certain route never would",
#  'SouthwestAir get kind update delayed flight Boston Houston 7:30 Really need back home tonight',
#  'SouthwestAir impression hour delay flight equipment failure compensation offered',
#  "SouthwestAir Looks like 'On February open schedule sale October know time",
#  "would appreciated please n't send page long form amp limited character Direct email",
#  'USAirways email',
#  "united diverted missed connecting flight told bag 's way MSY people care",
#  'united need assistance Line door travelling kid',
#  'united put together serious email issue arose vacation due staff post',
#  "upon entering plane USAirways stewardess `` water '' `` n't please take seat ''",
#  "JetBlue amount money spent hotel WEEK bc flight Cancelled Flightlation another flight n't make money lost",
#  'USAirways Flight CLT Phl 1st list.Someone else got spot Rude employee coach Wouldt give ID Said cute red head',
#  "thanks Bummer Poor planning part assume card Passbook wo n't work either",
#  'USAirways still crickets customer service',
#  "united 1k 'm always hoping improvement",
#  'merger USAirways usairwis cluster inefficiency misinformation going done',
#  'SouthwestAir much respect',
#  'SouthwestAir really easy local get strip book',
#  'USAirways Charlotte Staff needs prayer ... .disappointed response mishap ... ... lotttttttt pissed people',
#  'SouthwestAir unscheduled aircraft change please better system place worth paid upgrade REFUND',
#  'united air Another missed cnxn 2day ATC went strike Belize family amp miss cnxn EWR Please see DMs',
#  'USAirways thanks bad make two day train trip look appealing',
#  "united getting ridiculous 're missing connection",
#  'united really clean food coffee stain area around seat new passengers come aboard Gross',
#  "united Missing flight attendant Delayed Flight Prime example person impacts 's people HNL gt IAH UA252 wastedtime",
#  'USAirways call number listed sure next Friday get real live person line //t.co/8TJUuM22dD',
#  'change fee price new ticket ... logical',
#  "Stop madness RT JetBlue fleet 's fleek //t.co/7x9uSbj2FV",
#  'united ok sent u info via DM appreciate help consideration 😊',
#  "SouthwestAir Service rep n't say dumb tone voice like known",
#  'usairways im trying get dads wheelchair one answering Dulles.we tried call back on.multiple time',
#  "usairways 've hold approaching hr issue changed ticket online Frustrating",
#  'united thank',
#  'united thanks effort get earliest Though make complaint refund losing one business day tomorrow',
#  'USAirways lack communication offices customer amp yall never update ur system U guy established mess',
#  'JetBlue much paid fees Plus hotel food change could flown reliable airline no2jetblue',
#  'seriously want work JetBlue social team RT JetBlue vincenzolandino //t.co/eiGaJyzcW2',
#  "SouthwestAir right 're delayed 'm crabby Also allow one family member purchase EarlyBird check hold row",
#  'united guy suck',
#  "united Thank person Houston could get flight routing Newark NJ 'm going SFO",
#  'united lost bag Huston leave Bahamas cruise today nola buy new stuff Customer service non existent',
#  'SouthwestAir Thx customer service rep ALEX patient help reFlight Booking Problems Cancelled Flighted flight getting us tmrw',
#  'usairways faster way get Columbia Sc making stay CLT night delayed flight',
#  'highly disappointed baggage service merge USAirways guy lost 1st bag missing item',
#  "SouthwestAir A-list program complete JOKE company value loyal customers.Time look another `` go-to '' airliner",
#  'understand need drain lavatory fearing freezing policy checking boarding smh come ...',
#  "united n't hope nicer flight time try thing right sold ticket connetion",
#  'SouthwestAir Thank Thank Thank last attempt win DestinationDragons ticket success could happier',
#  'jetblue hate 😒 http //t.co/g4WwR6VBRQ',
#  'CVGairport get together perfect combination delay Cancelled Flightlations',
#  "united may `` dislike delay '' paid .We agreement paid got destination certain time",
#  'SouthwestAir trying get cust relation another use',
#  "JetBlue yesterday flight want Chicago sale within point range today n't way guy still honor",
#  'united possible add Known Traveler Number ticket Flight Booking Problems',
#  'VirginAmerica heyyyy guyyyys.. trying get hour someone call please',
#  "😐 “ JetBlue fleet 's fleek //t.co/QavvlAXLkl ”",
#  'SouthwestAir Thanks opportunity ...',
#  'JetBlue disappointed missed connection ROC SLC reimbursement even tho friend pilot say due ATC',
#  'JetBlue lipstick pig still pig Ur new baggage claim SJU disaster chair mins+ wait baggage fail',
#  "prime ticketed seat get switched AA sure 's going ...",
#  "“ JetBlue fleet 's fleek //t.co/g12sn5qsqZ ” ... Yall better",
#  "JetBlue 's great Thank",
#  "usual next flight show time 's suppose leave minute n't boarded",
#  'SouthwestAir Opal Dragon book Dragon ALI woven murdering ways Philippines Australia //t.co/c9p2ioSphM',
#  "USAirways happen n't located",
#  'phone call email Cancelled Flight flight would lovely',
#  'USAirways please thank Mellie CAE Tammy baggage claim CLT excellent customer service 2day complaint',
#  'united mean within one week filed compensation complaint website',
#  'united thanks help ... got need issue _austrian guess sit awhile longer',
#  'USAirways airline rather poor right SLC waiting take suppose take hour minute ago',
#  'USAirways three hour hold disconnected Conf EBHSET Need home Sunday interview',
#  "USAirways 's flight gate agent plane PHX B18 Nice customer service",
#  'united Unfortunately bad experience flying Saturday Inpolite crew bad delay',
#  'USAirways US stated issue plane moving cargo door open plane Umm ok. little strange',
#  'united thanks trying take money without notice industry Cancelled Flight service refund issued Cont…',
#  "united Ca n't leave Tarmac ..united 's gate agent agree head count min counting people max epicfailunited",
#  'USAirways flight delayed hour reason given Sure love flying airline whatajoke',
#  "united vacation 's going ruined w/ days rain change fee us nearly cost original flight help",
#  'SouthwestAir way help entry Vegas event Boyfriend amp Imaginedragons fan since awesome',
#  'thought guy done messing make worse airline ruin hope dream',
#  'boarded flight 8:30am 11:40 Still sitting runway Lots fun',
#  "USAirways waited hold long n't wait hold forever never received confirm 1st place help",
#  'united interviewed yesterday flight attendant last person recruiter say lost file n come back interview',
#  'united Item mine mysteriously ended checked bag EWR YOW flight Missing black box //t.co/SJQEmDtQmA',
#  'united thank trying two days set',
#  'SouthwestAir WiFi shit fix jump closest bloody fucking emergency exit',
#  'VirginAmerica jump Dallas-Austin market Dallas_News //t.co/EwwGi97gdx',
#  "SouthwestAir n't conference number spoke Courtney Texas David finally fixed mine hour",
#  "n't anyone make better effort retain customer easy fix want travel AA",
#  'united Premier desk able rebook friends problem pay checked bag',
#  "“ JetBlue fleet 's fleek //t.co/g97HAbyeP5 ” SMH",
#  'SouthwestAir guy held flight Thank take MDW Oakland Thanks',
#  "united Flight 211/ORD gate agent tried prevent take onboard bag 've used year Flight crew reasonable",
#  'USAirways thank',
#  'USAirways success make flight please thank crew great time recovery',
#  "SouthwestAir considered adding `` 'll call back someone free '' feature support line",
#  'SouthwestAir Vegas days ago Miss Warm Weather',
#  "united unsmiling rep. told us hotel shuttle come `` like every minute '' Breezy min Late Flightr 're take cab going reimburse",
#  'send trusted traveler ID add reservation tsa pre',
#  "thank ... know 's busy today help would appreciated ...",
#  'JetBlue still waiting bag flight landed hour ago',
#  "USAirways 1st reaccommodation delayed flight one amp Gate Agent still n't mumbled word Folks getting anxious",
#  'USAirways Dude named Shaquille desk Charlotte incredibly professional helpful vs. crazy angry people tonight',
#  'SouthwestAir Kudos adding Passbook app LOVE',
#  "united worse oh ca n't delayed reason way Lon flight Cancelled Flighted REASON le days returning",
#  "USAirways find funny PHLAirport responds n't customer service worst wedontcarebecauseyoupaidalready",
#  'jetblue WTF stuck JFK 2+ hr delay Boston cuz u say snow snow weather map WTF',
#  'JetBlue thank guy awesome',
#  'fat man stuck airplane bathroom',
#  'USAirways sorry meant flight supposed depart 5:00 say 6:30 issue',
#  'united received one previously 11th checked Odd say complaint associated e-mail',
#  'JetBlue definitely new favorite airline',
#  'united baldordash Rebooked arrived hour Late Flightr Last year hr San Diego inflight entertainment',
#  "JetBlue Although n't totally answer looking appreciate prompt response",
#  'SouthwestAir easily get Atlanta show need ticket help',
#  'JetBlue whatever lil mint heart desire //t.co/WmX12F33ZC',
#  'message pic sent ...',
#  'thanks',
#  "united `` Airport snow removal method ... '' Keep good work folks Cessna 's become 's //t.co/9v8tMUsJvU",
#  'USAirways ability switch flight tell bag',
#  "USAirways make Bahamas work luggage n't know travel happen anyway get help/info",
#  'USAirways NEVER fly us airway american share nightmare story many others know fly',
#  'united Delayed hr flight PIT/IAD finally board plane sit half hour amp crew hr limit amp deplane Unacceptable',
#  'SouthwestAir hold minute fly answer phone',
#  'AA Cancelled Flightled flight without courtesy notifying us alternative poor',
#  "USAirways 2nd time occurred week 'm patient choice Antitrust issue",
#  'SouthwestAir hold rebook flight CMH 1.5 hr rebook website crashed',
#  'VirginAmerica YES FYI BFF',
#  "JetBlue 's delay system n't",
#  "VirginAmerica 'm trying check 10:50AM CT flight tmm desktop website 's working sort cache bug SOS",
#  'VirginAmerica beautiful front-end design right cool still book ticket b/c back-end secure',
#  "united 'll hearing sure",
#  'JetBlue Annnndddd booked flight easy',
#  '’ line waiting minute',
#  'USAirways flt 2rsw could extended courtsey waiting 2min us ... gate closed r face Ur fired',
#  'USAirways last name Pordes',
#  'thanks actually make connection flight delayed Guess delay bad thing //t.co/XGgCNTco8m',
#  "n't know may also working home Thanks nothing",
#  'USAirways know left something last flight literally run make connection retrieve please',
#  'JetBlue offered flight 4/19 paid changed it.This 2nd time done ruin cruise plan',
#  'united say customer care report anyone response humiliating company serf public',
#  'united sitting middle first time .. Hope work well',
#  'JetBlue Airways Corporation NASDAQ JBLU Update JetBlue say Lufthansa ... Markets Bureau //t.co/aPY3zLSqUu',
#  'malhoit least got response via Twitter went yesterday',
#  'Please help AA Monday Cancelled Flightled advise reFlight Booking Problems refund children need make plan',
#  'USAirways seat next 19B flight Seattle tray table fall ... //t.co/HAJ5lKqjW4',
#  "united flight ua3576 gate b1 tell ray somehow make flight IAH n't wait one",
#  'USAirways comcast airline 2hrs35minOnHold',
#  "“ `` Jason 'll end missing connection Please see DFW agent assistance. ” Nope n't take yet still",
#  'SouthwestAir hold 2.5 hour waiting speak someone Cancelled Flightled flight Philly ORL',
#  'PatrichRuben profit maximization top priority Nothing else even register dinosaur',
#  "SouthwestAir Flying week bringing blanket bc 's freezing 😜",
#  'united great flight PVD Smallest plane ever smooth landing ever',
#  'thanks submitted damage bag complaint online ... anything else goodcustomerservice',
#  'Eagle always Late Flight',
#  'looking status flight schedule 5:15 tomorrow morning thank',
#  "Hypocrisy RT united gg8929 'm sorry 're able offer full refund exchange rate hoping ^KP",
#  'United terrible illogical re-route Cancelled Flightled connection make pay check bag lost bag ual',
#  'united speaking United customer service rep night flight confirming everything ok reservation..',
#  'USAirways Good news got fixed',
#  'USAirways word whether flight Seattle Charlotte connection held ...',
#  'southwestair important accept others SWADiversity',
#  'changed AAdvantage travel plan amp call 800-433-7300 get help sea ur busy amp hang give',
#  'SouthwestAir everyones flights Cancelled Flightled today DESERVE',
#  'USAirways airway joke never dealt worse service',
#  "JetBlue reading NYTimes “ JetBlue fleet 's fleek //t.co/lvIrTDtqly ”",
#  "SouthwestAir really unhelpful ca n't rebook online //t.co/N5O43sVl8i",
#  'JetBlue Flight full',
#  'USAirways 1-2 Rock hit plane delay Never easy day US Airways Ya never fail let',
#  "JetBlue thank 'm excited fly first time",
#  "united gate DEFINITELY FULL parked wheel chocked Customer service call `` UNMET ARRIVAL ''",
#  'SouthwestAir provide direct assistance colleague re-book b/c ticket booked via corporate account help',
#  'Aww JetBlue guess need book flight somewhere warm ASAP suggestion',
#  'united never flying guy ever customer service piss poor best',
#  "Yes Thanks much 💜 “ united whitterbug see spoke Reservations team 've reinstated flight Thanks ^EY ”",
#  'USAirways anyone answering phone today Listening damn message 1:10 minute',
#  'SouthwestAir Thank',
#  'beyond redemption Jfk Baggage claim look like luggage warehouse',
#  'united know two hour us sitting plane bag loaded plane weight',
#  'Deplaned 3rd fucking time Fuck AA',
#  'united Joni great job flight LAX Thanks great flight',
#  "'m willing hold agent n't helpful keep hang americanairsucks hiremorepoeple",
#  'united delayed another hour',
#  "USAirways `` admiral club '' CLT rude ignorant front desk staff ... fall far ... THANKS DOUG PARKER",
#  'JetBlue booked work added upgrade seat Need upgrade receipt',
#  "SouthwestAir Hi Janet customer service 'm call back sitting que min Plz pick frustrated",
#  "flight delayed amp ca n't talk reach anyone customer service high call volume",
#  "united u miss first leg ur flight pay hundred 's keep second leg much keep earn mile",
#  'united standby Denver delayed confirmed Aspen whose flights Cancelled Flighted day confidence',
#  'JetBlue actually flight',
#  "united options co tonight n't look like UA5525 make time UA6259 reserve hotel room",
#  "SouthwestAir thanks much make Cancelled Flightlation 've sent u info",
#  "united 'm aware flight detail thanks Three hour Late Flight crew could give le shit",
#  'united UA1740 admit clue flight leave Denver unfriendlyskies',
#  'JetBlue Thank JetBlue Credit Nice save',
#  'lost customer today Flight today Cancelled Flightled find call customer service yesterday',
#  'still waiting flight ... get money back',
#  "united already emailed n't know expedient contact Please advise Thanks",
#  'SouthwestAir flight Cancelled Flightled ... tried get refund hold get flight would departed',
#  "SouthwestAir thank help resolving problem Shannon ROCKS even though Rhonda n't",
#  "united still n't received response Please direct message contact information",
#  'USAirways future better harsh weather preparedness plan much staff call everything snowballed',
#  'united airline cause missed connection u would think would take whatever step remedy screw',
#  'united poor old United never seem get response right',
#  "USAirways nvm bad 's hour half thanks",
#  'USAirways Thanks',
#  "USAirways know 're dealing weather PHLAirport hot mess Pls send reinforcement",
#  'SouthwestAir amp sammi_jon3s best friends Imaginedragons chance could get ticket DestinationDragons',
#  'thx responding cant watch min film w/out cutting prolonged prds time beyond frustrating',
#  "united sure missed mark tonight 's redeye LAX Chicago mess better",
#  'united yes awful weather appears get home',
#  "JetBlue 2nd time row flight jfk disaster Last time n't allowed fly stndby hour delay w/out notification",
#  "USAirways hold minute need help USAIR wo n't help",
#  'flight dfw gsp going Cancelled Flightled tomorrow',
#  'united flight 2/23 Thx',
#  'USAirways good luck getting cool',
#  'USAirways long departure gate stay open make connecting flight RDU flight',
#  "USAirways mad ca n't even believe guy Cancelled Flight connecting flight leave first stop amp give useless hotel voucher",
#  'SouthwestAir ridiculous want charge change flights even multiple seat available flight needed',
#  'SouthwestAir Another delay Wow',
#  'trying check flight line working amp agent busy take call',
#  "JetBlue 's going LGA-FLL..poor communication gate agent",
#  "southwestair ftw ✈️ Hope 'll sing us song flight Phoenix today Terminal Humphrey http //t.co/mAvIgetbBw",
#  'united ... lie lie lie ... .still sitting gate moved inch //t.co/LulGnwEfFH',
#  'united following need follow DM',
#  'USAirways Total lack cust service mom flying solo w. baby flying w. Air',
#  "united n't ever print known traveler number ticket never get use TSA prescreen paid",
#  'still think American Airlines great ... would like treated better Loyal customer first right',
#  'USAirways delay mechanical issue weekend flights Ridiculous tweet long delayed',
#  'united future delay cause hour wait slept night airport ensuring seating choice replacement flight would good',
#  'break whatever want take responsibility..Too bad customer medium filmcrew chicagotribune WSJ nytimes CNN',
#  "USAirways call time redeem mile point ca n't get advertise mile make hard use",
#  'jetblue directed mobile website direct link GET TOGETHER',
#  "USAirways 's going CLT",
#  "united could n't possibly messed trip anymore Thanks terrible airline disappointed",
#  'united app say flight UA936 ZRH departed 2:45hrs Late Flight hour Late Flightr still seating inside plane IAD fail',
#  "united mean beyond opaque `` maintenance issue '' yes would basic customer service EWR staff ca n't manage",
#  'SouthwestAir Free TV watch Daytona Boss //t.co/SbGBN7oUXy',
#  "USAirways screwed big 1st flight 1hr Late Flight Made 2nd flight CSM daryl would n't let plane 1/4",
#  'USAirways option use twitter people working u clue tell go A4 b16',
#  'VirginAmerica hot female pilot Sweet DCA SFO',
#  "southwestair kudos rep `` Patricia '' gate B11 Sunday morning Chicago Midway MDW … //t.co/MmCWkqp2gy",
#  'JetBlue able watch Oscars flight tomorrow',
#  'JetBlue Airways Covered Bank America JBLU Dakota Financial News //t.co/WOwxhpU5qv',
#  'VirginAmerica Sent couple message email provided avail try next year Cheers',
#  'USAirways plan support ApplePay board USAirways MC would nice still use forget card',
#  "JetBlue 're home guy recovered laugh extra day barbados open Cuba soon",
#  'united FernHeinig18 delay due making back gate multiple time Maybe take accountability',
#  "RT JetBlue fleet 's fleek //t.co/ncguZDgDaQ",
#  "'s weather 's logistics hold minute call get desk agent",
#  'JetBlue would prefer similar picture full E190 tail great shot',
#  'USAirways denied mom flight NEEDED breast pumping part full flight Please FIX ASAP freeflight',
#  'USAirways service Philly unacceptable Look better service✌️ yr old shouldnt hard time //t.co/WDAKTmr7Mj',
#  'JetBlue knew 3-4 hour sounded odd missed flight hit JFK hour early gate attendant told us 3-4',
#  'USAirways Gainesville FL',
#  'SouthwestAir never got email confirmation ticket credit card charged Phone wait time crazy chat',
#  "JetBlue Gotcha ... `` lessening delay '' ... part 's happen right",
#  'none sample itineraries actually booked //t.co/mF7rABGn8a Every last leg back US say invalid',
#  "united 'm familiar procedure would n't first time UnitedAirlines lost one bag unhappytraveler",
#  'USAirways hour delay pho-mia airline bad getting worse Foolish american merge treat customer like crap',
#  'USAirways friend telling gate attendant stewardess going notourfaultyoudontuseyourgatesright',
#  "HS student Ithaca NY stuck Miami flts xld u wo n't rebook get kid home use carrier alliance rulesshouldbend",
#  'united even legal guy advertise flights cant honor',
#  'SFO Natt agent helped really awesome job',
#  "SouthwestAir stop ur b promos ✈️anywhere starting click everywhere 'd fly=130 place thats CLE NoThanks",
#  'USAirways SVLLINDIA provides best logistics experience people India Mumbai Surat NaviMumbai',
#  'loaded luggage plane hour delayed Flight293',
#  'VirginAmerica best flight attendant ever //t.co/PxdEL1nq3l',
#  "USAirways please respond 've hold reservation line hour minute would really appreciate",
#  'USAirways wow.. Flight Cancelled Flightled slept floor airport flight delayed',
#  "united phone number ca n't find call flight reservation",
#  'USAirways make Huge relief thanks help',
#  'SouthwestAir early bird great employee awesome passengers killed buzz',
#  "united strike board anyone 's something wrong plane Common sense",
#  'Also way speak someone phone 1-800 hang day',
#  "united mention PLANE luggage luggage 'm going many days",
#  'united day flights',
#  'JetBlue flight Orlando ... ridiculous wait high school band board notbabysitters whrsthecoach',
#  'SouthwestAir THANK MUCH ACCESS DestinationDragons TONIGHT theTroubadour 😁 Imaginedragons Crying /dying rn ripme',
#  'USAirways Need help flight Weather funeral tough combination hold hour Please',
#  "SouthwestAir Thanks helping mom allegiantair would n't let get plane Orlando 're best customerservice",
#  'USAirways incompetent airline every day days end',
#  'Mistake multibillion dollar company',
#  "USAirways thx replying trying get thru many time amp v-mail people hang us talk tech ... cont 'd",
#  'JetBlue gracious jetblue tell go BUY water snack flight delayed hour',
#  'SouthwestAir would',
#  "SouthwestAir 've never met favorite band would sooo amazing win destination dragon",
#  'united recap bounced flight LIED hung supposed think/do',
#  "united wife sharing dreadful experience n't pretend UA care young girl traveling alone United Airlines",
#  "united would help integrate App `` activate '' surf ...",
#  'CLT left gate next CLT Need help',
# ...
#  'JetBlue dispatcher keep yelling hung',
#  'JetBlue thank guy best 🙌✈️',
#  "united Friend O'Hare ca n't get flight bc say proof bought 1st class tkt boarding pass",
#  "SouthwestAir well 'm sure bad experience already",
#  'JetBlue drop take two people vice versa back forth',
#  'btr trained gate agts Im frequent fly amp nvr issue w/my bag 2day forced gate check priority boarding',
#  'united chance flight EWR PIT Cancelled Flighted tomorrow',
#  'united two year old Birthdate 11/13/2012',
#  'SouthwestAir Flight Booking Problems Late Flight summer travel AUS-CUN direct flight disappear',
#  "believe long flight PHI take know 's US Airways would really like get home",
#  'united boarded UA1297 refused carry overhead bag space plane load space fail customerexperience',
#  "united 'm say make flight poor/non-communication unaccounted lost time amp lot frustrated flyers standing around",
#  'united ehsanisMpowered lmfao',
#  'SouthwestAir tfw1 JimCramer AARP TY-Spent total hr min holding Cell battery died Finally make arrangement w kind Rep',
#  "united 's allowed 's allowed carry checked baggage",
#  'USAirways US pilot started flight announcing arrival Gatwick Heathrow Moments concern aboard',
#  'united one lady helping us luggage',
#  'United thanks Lea Chicago office help switching Cancelled Flighted flights',
#  'SouthwestAir great flight great view //t.co/auFM4xdaj2',
#  "lost cat missed flights kept crated hr would-be hr trip 'll never touch pet",
#  'united U BUMS U LOSE BIGGEST BAG FLIGHT',
#  "'s frustrating -- PAID get refund",
#  'Thank info Changes need make phone correct way AA agent call directly',
#  'united make fly list airline wait connector Late Flight Stuck IAH',
#  'JetBlue Sure go south breakfast though Delayed three hour',
#  'respond DM',
#  "'s 16+ extra hour travel time Missed vacation time guy messing professional life",
#  'united USAirways americanone one bag Claim want MGA',
#  "told us drive back drop could attempt fix Really n't time terrible",
#  "united thanks moving dad mom 's flight helped make birthday start FriendlyFriday Awesomeness paw",
#  'VirginAmerica flight delayed hour LA due mechanical problem Handle like pro could tossed us free drink',
#  'thanks',
#  "JetBlue customer service say since wife setup family account ca n't join mine year Help fix please",
#  "giving hard time ... looking basic customer service AA lost bag ETA 's return please",
#  'SouthwestAir yeehaw found us another plane Thx listening vent',
#  'friend flight Cancelled Flightlations LAX CMH Feb Anyway help number help',
#  'SouthwestAir Jackpot legroom //t.co/ZO2iceG4lI',
#  "USAirways 's point baggage claim ticket n't scan tracking",
#  "united Cancelled Flights flight sends email say `` think next flight ... '' customer outrage //t.co/KkwiwI97A4",
#  "united trying go far away King'sCollegeLondon possible charity today Would help us jailbreak RAG",
#  'united live abroad Flight Booking Problems flights come visit state',
#  'united FirstClass London way LondonFashionWeek LFW15 👠🇬🇧👠🇬🇧👠🇬🇧',
#  'JetBlue ask load bag flight',
#  "USAirways 'm stuck airport fresno trying beat storm pittsburgh guy offered nothing HORRID",
#  'SouthwestAir SwagglikeBean take',
#  'SouthwestAir please please please answer phone',
#  "ever wonder find responding many customer complaint twitter 's airline suck",
#  'days BAGs amazing way neglect customer',
#  "USAirways 's deal flight computer network",
#  'SouthwestAir thing changing ticket Cancelled Flighting current ticket amp buying replacement online',
#  'SouthwestAir JasonWhitely flt Emer stop Albuquer heart condition crew awesome pilot Maverick divert',
#  'JetBlue Complete waste entire day Pathetic',
#  'united DM detail back 02/14 started phone number reach reply either online phone',
#  'united go segment SFO -- New York RT delayed hr suck BAD Maybe another line bus',
#  "USAirways 'm frequent fly US airway 'm qantas still get notifications Thank",
#  'finally make chicago hour Late Flight get food voucher wait.about 1per/hr Never Good bye',
#  'welcome anyone work condition deserves thank even though side Atlantic lol xx',
#  'SouthwestAir website downnnnn ugh',
#  'united cell phone record needs checked see conversed trust FAA handle better',
#  'united us stranded flying New Orleans Huston tonight stuck two days Rather fly wait',
#  'united force us check baby bag overbooked flight complains wife need much baby.. united baby meal',
#  'SouthwestAir IM THO 😭😭💔💔💔💔💔💔💔',
#  'got gate time watch plane push back minute needed Glad ’ relative nearby',
#  "hour 'm patient n't call back feature pay someone answer phone tweet onhold",
#  'Nice AA employee making skillful excuse Late Flightness due cater snafu ... //t.co/YPVPVdlTYs',
#  'JetBlue safety first lovejetblue',
#  'thanks airline ruined bag refuse anything',
#  "Ca n't unload flight jetway broken step planB waiting nearly hour",
#  'USAirways six hour even gate agent got fed left us line front empty desk Stay classy US Air',
#  'united tonight make Fred Flintstone happy upgrade 1st class //t.co/gKgKZLAwpR',
#  'united Asked Flight attendant typical compensation would amp say might get free TV Unacceptable',
#  'SouthwestAir Yes bag come straight hotel Thank ... guy rock',
#  'united Hi flying IAD tomorrow evening expect delay Cancelled Flightlations snow storm',
#  'united CMH gate staff disaster.. overbooked volunteer boarding min Late Flight trying figure issue bringbackrealstaff',
#  'VirginAmerica problem link email check-in thanks',
#  "SouthwestAir nvm gate say 're holding connection Thanks quick response",
#  "terminal LHR aa5/BA1506 n't say boarding pass",
#  'USAirways charged flight Cancelled Flightled unbelievable unheard',
#  'SouthwestAir Flight Cancelled Flightled BNA ... reschedule travel funds put back account future use',
#  'VirginAmerica match AmericanAirlines status Cool',
#  'USAirways satesq there one flt PHL-CRW per day',
#  'karabuxthomps Yeah lot question number one dare',
#  "SouthwestAir Thank know ya 'll ca n't control weather appreciate ya 'll working get flight rebooked last two days",
#  "JetBlue ca n't n't acces phone rn iPhone broke would rather change Late Flightr",
#  "united service far horrid want end trip high note Guess 's option",
#  'united flight frustration boiled dealing attendant attitude ridiculous',
#  'JetBlue family excited see too😊😊',
#  'united customer service 16hr delay coupon redeemed website higher price Expedia call wait time 55mins',
#  'united thanks keep good work',
#  "SouthwestAir temporary site glitch longer offering flights GRR GEG Feb Ca n't find online",
#  "USAirways AskPayPal completed 's case still say `` progress '' Paypal 's website reserved 13th",
#  "SouthwestAir- Wife 's RR pt expired days ago planning Flight Booking Problems trip today Anything us tight budget ...",
#  'SouthwestAir hold minute trying rebook Cancelled Flightled flight companion ticket Help',
#  'USAirways worst experience time never ever ever travel EVER',
#  'went check flight hr advance husband seated separately 6hr flight happen',
#  'USAirways GregWallace66 Yea give cent dollar',
#  'second pic CDG',
#  'SouthwestAir thank',
#  'united thanks',
#  'united okay Thanks',
#  'really appreciate great customer service ... One service agent hung asking legitimate question',
#  "SouthwestAir Still n't heard thing",
#  'chariot tonight angle look like //t.co/3ZZKQWWbJz',
#  'USAirways flight4592 LET US PLANE please go gate absurd',
#  'JetBlue sorry specified meant ground traffic trying get terminal',
#  'us air point combined',
#  'USAirways hold reservation min already worstairline',
#  'SouthwestAir contact missing Rapid Rewards credit',
#  "JetBlue 's poop barely work",
#  'USAirways still rep talk days Late Flightr U r asking checkin flight tmrw refund requested Deal w',
#  'JetBlue haha TY know time lane opens Logan',
#  "USAirways happen u could n't get us home next day flydelta flysouthwest flyjetblue theyareallbetter stillnobags",
#  "“ JetBlue fleet 's fleek //t.co/tLGoihqkvS ” 😐 make stop",
#  'JetBlue Customer year //t.co/epqqONHO2H',
#  'Extend rtn flight bereavement 22nd could change fee dropped told no.Worse day life badcustomerservice',
#  'SouthwestAir App Updated Passbook Support //t.co/WrWqrUblPs via ubergizmo',
#  'JetBlue sooo earlier say couldnt fly school trip 😏',
#  "united took screenshot emailed Let 's DM figure",
#  'USAirways kidding Oy',
#  'USAirways flight full',
#  "USAirways Stuck Philadelphia airport hour due `` maintenance '' Dreading flight back home Disgusting",
#  'SouthwestAir service promotion moment ModeloDeNegocio innovation innovacion BusinessModel',
#  'united new delay right //t.co/96fTLZWtvO',
#  'united Hello United take care call center Mexico City Office Terrible attitude lady helping',
#  'JetBlue offer service Daytona Beach New York Albany Business Review //t.co/dUhBJ41jHx',
#  "'m trying choose seat every time go next flight get system error",
#  "JetBlue ... n't heard anyone week nonstop flight baggage lost/stolen customer service 👎",
#  "JetBlue 've delayed almost hr take JetBlue 've good luck today really frustrating",
#  "JetBlue w/ upgrade Unsure ca n't switch someone around call hr advance reason",
#  'JetBlue Great thanks',
#  'united thank getting daughter home Cancelled Flightled flights Nashville',
#  'united yes ... ride home would perfect.. fete one would assume possible charging domestic flight ... Ps deplaned',
#  'SouthwestAir Totally ruined birthday weekend Cancelled Flighting flights reason offer point drink transport nolove cali',
#  'united nope need little red stamp counter Check wreck son //t.co/0pRGySvuRm',
#  'united referral program Milageplus explorer card',
#  "guy fail again.. need use voucher ticket ca n't online yourphonesystemsucks",
#  "SouthwestAir look like yr anni trip replaced w someone 's itinerary Worried abt c flight //t.co/BApE6RuMNE",
#  'thanks finally letting get book flight Frustration set ... donedeal talktoahuman',
#  'united took one window Also fun get motion sick //t.co/m81rV0blxs',
#  'JetBlue keep getting better water plane',
#  "JetBlue thank Hopefully 's soon supposed leave 11:23",
#  "united Thank y'all amazing airline know treat customer guy rock",
#  'SouthwestAir sent looking functionality app though one click action',
#  'need help record locator bringing TWO different flights system One op AA amp one US Airways',
#  "JetBlue 's okay ... 'm actually tea kinda guy anyway Thanks",
#  "united Held almost minute promised free movie n't work neither wifi paid Boo",
#  "'s baggage handlers call DFW today luggage onboard plane",
#  'USAirways would go though entire process get people phone usairwayssucks',
#  'USAirways crazy Treated mom poorly happy usairwaysfail',
#  'SouthwestAir many left',
#  'USAirways work hard making sure thing flow smoothly Keeping positive',
#  "USAirways n't blame weather Rep counter cost entire day weather Printed Boarding Pass Late Flight TakeResponsibility",
#  'united thanks updating 1+ hour delay exact second got ATL 🙅🙅🙅',
#  "united considered `` time '' 's arriving destination half hour Late Flightr scheduled //t.co/YMFTw1uyHr",
#  "rebooked n't get notified Cancelled Flightled",
#  "USAirways ShoutOut Kristie sp Gate4 PVD today 's RockStar tremendous help tough situation PromoteThatGirl",
#  'united check-in luggage Employee told include wheel dimension',
#  'united minute hold hr min ABC11_WTVD',
#  'USAirways guy screwing trip Thanks nothing lazy',
#  'united passengers waited inside flight runway returned back gate count valid journey',
#  'USAirways Frustrating days flights home changed airline Thank PHL USAirway employee amp united help getting back IAH',
#  "united u guy changed age double booked seat 've even though platinum person none",
#  'USAirways Cancelled Flightled last part ticket confused email received whether value remains someone ask',
#  'united business decision make inconvenience possibly cause lost customer good business decision Cranky',
#  'USAirways flight got Cancelled Flightled Charlotte hold hour pls pick',
#  'VirginAmerica wow blew mind',
#  'AA2416 time awesome flight Great job American',
#  "SouthwestAir n't realize clothes hotel suggestion",
#  'SouthwestAir got mine time wife 15th anniversary',
#  "“ SouthwestAir pancho_joe must 've heard us wrong Sweet mixtape though '' record n't leave 's 's left",
#  'Sitting gate Flight hour due Sabre backup plan place Sabre fixed',
#  "SouthwestAir favorite airline 've never issue Plus crew entertaining",
#  'USAirways make Thanks help',
#  "USAirways utterly unreliable n't schedule pilot US624 flight Seattle flights delayed usairwaysfail",
#  "southwestair TREMENDOUS job Atlanta Airport saw SW celebrate Mardi Gras Another reason 'm nuts guy //t.co/8WBzOrRn3C",
#  'united seems like one United help Lots finger pointed zero people stepping least gate Oreos',
#  'SouthwestAir 8FKQW conf Thanks reply',
#  'united rebooked hour original flight say handle situation bad would understatement',
#  'flights leaving Dallas right Maui trying figure delayed flight going',
#  'SouthwestAir One heck airline //t.co/CyoOnZfTdC',
#  "SouthwestAir flying flight tonight 7:20 PBI- boarding position C-42 overbooked Really n't want bumped",
#  'JetBlue Clients got ZERO year career never thought possible.2 suitcases worth thousand Italian clothing robbed',
#  'USAirways Cancelled Flightled flight ... pay hotel',
#  'response incredible Truly amazed step take enhance customer relation Big thank 😄',
#  "wow Regina told ca n't file request lost bag statement finish travel get DC argg",
#  "united since international connection 9am 'm hoping thing",
#  'JetBlue day',
#  'united long take mile re-purchased expired show recieved email request been..',
#  "united probably least satisfactory airline 've ever Never fail disappoint",
#  'United Airlines Changing MileagePlus Program Winners Losers //t.co/F1yvAiO9ul //t.co/vGlx6Ykwqg',
#  "SeguineJ AA joke right line n't even accepting call right hang",
#  "united nonrefundable hence wrote n't make sense credit nothanks",
#  'JetBlue Even year earthquake ... Haiti still needs help rebuilding flyingitforward',
#  'USAirways despite mechanical issue many delay followed Cancelled Flightlation still getting Vegas thanks great gate agent',
#  'JetBlue excuse though gate change though',
#  'JetBlue may need minute layover min delay first flight',
#  'united get reimbursed hotel taxis Cancelled Flightation',
#  'yet receive assistance one agent securing new connection Many miss work tomorrow',
#  'USAirways British_Airways three hour flight delay phone 45min counting',
#  'Everyone else outstanding',
#  'united think rough moment w/ bad passenger earlier flight Things got considerably better Thanks',
#  'USAirways thanks',
#  'Cancelled Flightled ticket take two month ++ refund still waiting',
#  'USAirways ’',
#  'USAirways shout pilot FC attendant Eliz US Super strong crosswind landing Eliz super job throughout',
#  'united see coming get AggieMensGolf Hawaii 12thMan //t.co/G8DKa3Edhf',
#  'dfwairport together best part flying',
#  'united Late Flight future flights train staff better handle emergency situation ground staff Customer Service',
#  'united oh united much despise thee',
#  'United Airlines CEO Jeff Smisek Disloyal Loyal Workers //t.co/0cevY3P42b via HuffPostBiz',
#  'united 3/10 disappointed service missing connection hour delay cramped seat least app good',
#  'sit airport long periolodicly time plane nasty',
#  'united flight Houston',
#  'united fuck care 😢',
#  'SouthwestAir info DestinationDragons winner announced amp best friend hoping win thanks',
#  'SouthwestAir Thanks',
#  'SouthwestAir tweet weekend/ bad weather close customer relation center process refund Cancelled Flighted flights',
#  "SouthwestAir missing 6,000 point one account 're spread four assuming create account",
#  'united used committed ContinentalAirlines fly merger remember switched SouthwestAir CommunicationFail',
#  'united soon done article Thanks ~Tom',
#  "'re finding bc united rebooked us airline realized could n't get us home 're ORD",
#  'USAirways give //t.co/2eDgc6TbLs',
#  'USAirways ticket couldnt used bc unable get departing dest RSW bc blizzard BOS Told way use credit fine',
#  ...]

# %%
# Splitting the data
x_train1, x_train2, y_train1, y_train2 = train_test_split(train, train_output, random_state = 0)

# %%
# Applying Count Vectorizer on training data
count_vec = CountVectorizer(max_features=4000)
x_train1_features = count_vec.fit_transform(x_train1)
x_train1_features
# Out:
# <8235x4000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 73143 stored elements in Compressed Sparse Row format>

# %%
# Applying Count Vectorizer on testing data
x_train2_features = count_vec.transform(x_train2)
x_train2_features
# Out:
# <2745x4000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 24215 stored elements in Compressed Sparse Row format>

# %%
# List of features selected
count_vec.get_feature_names()
# Out:
# ['00',
#  '000',
#  '02',
#  '03',
#  '05',
#  '10',
#  '100',
#  '10a',
#  '10hrs',
#  '10pm',
#  '11',
#  '11am',
#  '11th',
#  '12',
#  '130',
#  '13th',
#  '14',
#  '15',
#  '15th',
#  '16',
#  '17',
#  '19',
#  '1hr',
#  '1k',
#  '1pm',
#  '1st',
#  '20',
#  '200',
#  '2015',
#  '20min',
#  '21',
#  '21st',
#  '22',
#  '23',
#  '24',
#  '24hrs',
#  '24th',
#  '25',
#  '26',
#  '27',
#  '28',
#  '2d',
#  '2day',
#  '2days',
#  '2hr',
#  '2hrs',
#  '2littlebirds',
#  '2nd',
#  '2pm',
#  '2x',
#  '2xdaily',
#  '2y',
#  '30',
#  '300',
#  '30a',
#  '30am',
#  '30k',
#  '30min',
#  '30mins',
#  '30pm',
#  '31',
#  '320008a',
#  '35',
#  '35pm',
#  '35x',
#  '36',
#  '3am',
#  '3d',
#  '3fq3xelbon',
#  '3hrs',
#  '3pm',
#  '3rd',
#  '3thparty',
#  '3x',
#  '3yr',
#  '40',
#  '40mins',
#  '40pm',
#  '40th',
#  '41g',
#  '42',
#  '428',
#  '4322',
#  '433',
#  '45',
#  '45am',
#  '45min',
#  '45mins',
#  '45pm',
#  '47',
#  '4am',
#  '4hrs',
#  '4ojrsdwpkk',
#  '4pm',
#  '4th',
#  '4ward',
#  '4x',
#  '50',
#  '500',
#  '50am',
#  '50k',
#  '50pm',
#  '51',
#  '55',
#  '55am',
#  '55pm',
#  '58',
#  '5am',
#  '5hrs',
#  '5pm',
#  '5th',
#  '60',
#  '64gb',
#  '65',
#  '6am',
#  '6hrs',
#  '6pm',
#  '6th',
#  '70',
#  '700',
#  '728',
#  '72rmpkogwu',
#  '7300',
#  '737',
#  '75',
#  '750',
#  '777',
#  '7am',
#  '7pm',
#  '7t1rdrcre6',
#  '7th',
#  '80',
#  '800',
#  '80th',
#  '8am',
#  '8aug',
#  '8hrs',
#  '8pm',
#  '8th',
#  '8wbzorrn3c',
#  '9am',
#  '9pm',
#  'a1',
#  'a320',
#  'a321',
#  'aa',
#  'aa106',
#  'aa2444',
#  'aa65',
#  'aa76',
#  'aa953',
#  'aadvantage',
#  'aafail',
#  'aarp',
#  'abandoned',
#  'abc',
#  'ability',
#  'able',
#  'aboard',
#  'abq',
#  'absolute',
#  'absolutely',
#  'absurd',
#  'abt',
#  'abused',
#  'abysmal',
#  'ac',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'access',
#  'accident',
#  'accidentally',
#  'accommodate',
#  'accommodating',
#  'accommodation',
#  'accomplished',
#  'according',
#  'accordingly',
#  'account',
#  'accountability',
#  'acct',
#  'accts',
#  'accurate',
#  'acknowledge',
#  'acknowledgment',
#  'across',
#  'act',
#  'action',
#  'active',
#  'activity',
#  'actual',
#  'actually',
#  'ad',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'address',
#  'addressed',
#  'adds',
#  'addtl',
#  'adjustment',
#  'admiral',
#  'admirals',
#  'admit',
#  'adore',
#  'advance',
#  'advantage',
#  'advertise',
#  'advertising',
#  'advice',
#  'advise',
#  'advisory',
#  'aerojobmarket',
#  'affected',
#  'affiliate',
#  'afford',
#  'affordable',
#  'afraid',
#  'after',
#  'afternoon',
#  'again',
#  'age',
#  'agency',
#  'agent',
#  'agents',
#  'aggravating',
#  'aggressive',
#  'agnt',
#  'ago',
#  'agree',
#  'agt',
#  'ah',
#  'ahead',
#  'ahold',
#  'ai',
#  'air',
#  'airbus',
#  'aircanada',
#  'aircraft',
#  'airfare',
#  'airline',
#  'airlines',
#  'airplane',
#  'airport',
#  'airway',
#  'airways',
#  'aisle',
#  'aka',
#  'alaska',
#  'albany',
#  'alert',
#  'alerted',
#  'alex',
#  'ali',
#  'alive',
#  'all',
#  'allende',
#  'allergic',
#  'allergy',
#  'alleviate',
#  'alliance',
#  'allow',
#  'allowed',
#  'allowing',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'already',
#  'alright',
#  'also',
#  'alternate',
#  'alternative',
#  'although',
#  'altitude',
#  'always',
#  'am',
#  'amateur',
#  'amazed',
#  'amazing',
#  'amazingly',
#  'america',
#  'american',
#  'americanairlines',
#  'americanview',
#  'amex',
#  'among',
#  'amount',
#  'amp',
#  'amybruni',
#  'ana',
#  'and',
#  'angry',
#  'anniversary',
#  'announce',
#  'announced',
#  'announcement',
#  'announces',
#  'annoyed',
#  'annoying',
#  'annricord',
#  'another',
#  'answer',
#  'answered',
#  'answering',
#  'anthony',
#  'anticipate',
#  'antonio',
#  'anxious',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'apart',
#  'apologize',
#  'apologizes',
#  'apology',
#  'app',
#  'apparently',
#  'appear',
#  'appears',
#  'appease',
#  'apple',
#  'application',
#  'applied',
#  'apply',
#  'applying',
#  'appointment',
#  'appreciate',
#  'appreciated',
#  'appreciates',
#  'appreciation',
#  'approach',
#  'approaching',
#  'appropriate',
#  'approve',
#  'approx',
#  'apps',
#  'april',
#  'apt',
#  'aqjn4hwnac',
#  'arbitrary',
#  'are',
#  'area',
#  'argue',
#  'arizona',
#  'arms',
#  'around',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'article',
#  'aruba',
#  'as',
#  'asap',
#  'ase',
#  'ashamed',
#  'ask',
#  'asked',
#  'asking',
#  'askpaypal',
#  'asks',
#  'asleep',
#  'aspen',
#  'assaulted',
#  'asshole',
#  'assigned',
#  'assignment',
#  'assist',
#  'assistance',
#  'assult',
#  'assume',
#  'at',
#  'atc',
#  'athlete',
#  'atl',
#  'atlanta',
#  'atlantic',
#  'atrocious',
#  'attempt',
#  'attend',
#  'attendant',
#  'attention',
#  'attitude',
#  'aug',
#  'august',
#  'aus',
#  'austin',
#  'austinairport',
#  'australia',
#  'auto',
#  'automated',
#  'automatically',
#  'avail',
#  'availability',
#  'available',
#  'avgeek',
#  'aviation',
#  'aviv',
#  'avoid',
#  'award',
#  'aware',
#  'away',
#  'awesome',
#  'awful',
#  'aww',
#  'b16',
#  'b4',
#  'b6',
#  'b737',
#  'b787',
#  'ba',
#  'baby',
#  'back',
#  'backup',
#  'bad',
#  'badcustomerservice',
#  'badge',
#  'badly',
#  'badservice',
#  'bae',
#  'bag',
#  'baggage',
#  'bags',
#  'balance',
#  'ball',
#  'baltimore',
#  'band',
#  'bank',
#  'bar',
#  'barbados',
#  'barbara',
#  'barely',
#  'base',
#  'basic',
#  'basically',
#  'bat',
#  'bathroom',
#  'bathrooms',
#  'battery',
#  'battle',
#  'battles',
#  'bay',
#  'bc',
#  'bday',
#  'bdl',
#  'be',
#  'beach',
#  'beantownmatty',
#  'beat',
#  'beating',
#  'beautiful',
#  'beauty',
#  'become',
#  'becoming',
#  'bed',
#  'been',
#  'beer',
#  'before',
#  'begin',
#  'beginning',
#  'behavior',
#  'behind',
#  'belfast',
#  'believe',
#  'believing',
#  'belize',
#  'belong',
#  'belonging',
#  'belt',
#  'benefit',
#  'bereavement',
#  'bergstrom',
#  'besides',
#  'best',
#  'bestairlineever',
#  'bet',
#  'better',
#  'beverage',
#  'beware',
#  'beyond',
#  'bf',
#  'bgm',
#  'bgr',
#  'bhm',
#  'bicycle',
#  'big',
#  'bigger',
#  'biggest',
#  'bike',
#  'bill',
#  'bin',
#  'bird',
#  'birmingham',
#  'birthday',
#  'bit',
#  'bitch',
#  'biz',
#  'bk',
#  'black',
#  'blah',
#  'blame',
#  'blamed',
#  'blaming',
#  'blank',
#  'blanket',
#  'blasting',
#  'blatant',
#  'blew',
#  'blizzard',
#  'blocked',
#  'blog',
#  'bloody',
#  'blow',
#  'blown',
#  'blue',
#  'bluecarpet',
#  'bluemanity',
#  'bna',
#  'board',
#  'boarded',
#  'boarding',
#  'boat',
#  'boeingairplanes',
#  'bogota',
#  'boise',
#  'bold',
#  'bom',
#  'bonus',
#  'boo',
#  'book',
#  'booked',
#  'booking',
#  'boot',
#  'bora',
#  'border',
#  'bos',
#  'boston',
#  'bostonlogan',
#  'bot',
#  'bother',
#  'bothered',
#  'bottle',
#  'bottom',
#  'bought',
#  'bounced',
#  'bound',
#  'bout',
#  'box',
#  'boy',
#  'boyfriend',
#  'bqn',
#  'brain',
#  'brand',
#  'brandmance',
#  'brazil',
#  'break',
#  'breakfast',
#  'breaking',
#  'breath',
#  'brian',
#  'bridge',
#  'brilliant',
#  'bring',
#  'bringing',
#  'bro',
#  'broke',
#  'broken',
#  'brokenpromises',
#  'brother',
#  'brothers',
#  'brought',
#  'browser',
#  'bruh',
#  'brushing',
#  'brutal',
#  'bs',
#  'btr',
#  'bttr',
#  'btw',
#  'buck',
#  'budget',
#  'buf',
#  'buffalo',
#  'bug',
#  'bull',
#  'bullshit',
#  'bummed',
#  'bummer',
#  'bump',
#  'bumped',
#  'bumping',
#  'bunch',
#  'bus',
#  'bush',
#  'busiest',
#  'business',
#  'businessfirst',
#  'bussey',
#  'busy',
#  'but',
#  'butt',
#  'button',
#  'buy',
#  'buyer',
#  'buying',
#  'bwi',
#  'bwi_airport',
#  'c19',
#  'c25',
#  'c26',
#  'ca',
#  'cab',
#  'cabin',
#  'cache',
#  'cake',
#  'cal',
#  'calendar',
#  'calgary',
#  'cali',
#  'california',
#  'call',
#  'callback',
#  'called',
#  'callers',
#  'camera',
#  'can',
#  'cana',
#  'canada',
#  'canadian',
#  'cancelled',
#  'cancer',
#  'cancun',
#  'cant',
#  'capacity',
#  'capital',
#  'capt',
#  'captain',
#  'captive',
#  'capture',
#  'car',
#  'card',
#  'care',
#  'career',
#  'cargo',
#  'carolina',
#  'carousel',
#  'carrier',
#  'carriers',
#  'carrieunderwood',
#  'carry',
#  'carryon',
#  'carryons',
#  'carseat',
#  'cart',
#  'case',
#  'cash',
#  'cat',
#  'catch',
#  'cater',
#  'cause',
#  'cb',
#  'cc',
#  'cdg',
#  'celebrate',
#  'celebrating',
#  'cell',
#  'cellphone',
#  'center',
#  'central',
#  'centre',
#  'century',
#  'ceo',
#  'cert',
#  'certain',
#  'certainly',
#  'certificate',
#  'cessna',
#  'cha',
#  'chair',
#  'chairman',
#  'challenge',
#  'challenging',
#  'chance',
#  'change',
#  'changed',
#  'changing',
#  'channel',
#  'chaos',
#  'chapter',
#  'char',
#  'character',
#  'charge',
#  'charged',
#  'charging',
#  'charity',
#  'charleston',
#  'charlotte',
#  'charm',
#  'charter',
#  'chase',
#  'chasefoster',
#  'chat',
#  'cheap',
#  'cheaper',
#  'cheapflights',
#  'check',
#  'checked',
#  'checkin',
#  'checking',
#  'checkout',
#  'checkpoint',
#  'cheer',
#  'cheers',
#  'cheese',
#  'chef',
#  'cherry',
#  'chg',
#  'chi',
#  'chicago',
#  'chicagotribune',
#  'chicken',
#  'child',
#  'children',
#  'chill',
#  'china',
#  'chk',
#  'chocolate',
#  'choice',
#  'choose',
#  'choosing',
#  'chose',
#  'christmas',
#  'chrome',
#  'cincy',
#  'circle',
#  'circumstance',
#  'citing',
#  'city',
#  'cking',
#  'claim',
#  'claimed',
#  'clarification',
#  'class',
#  'classy',
#  'cld',
#  'cldnt',
#  'cle',
#  'clean',
#  'cleaned',
#  'cleaning',
#  'clear',
#  'cleared',
#  'clearly',
#  'cleveland',
#  'click',
#  'client',
#  'clients',
#  'close',
#  'closed',
#  'closer',
#  'closest',
#  'clothes',
#  'clothing',
#  'cloud',
#  'clown',
#  'clt',
#  'club',
#  'clue',
#  'cmh',
#  'cmon',
#  'cnn',
#  'co',
#  'coach',
#  'coast',
#  'coat',
#  'cocktail',
#  'code',
#  'coffee',
#  'cold',
#  'colleague',
#  'college',
#  'columbia',
#  'columbus',
#  'com',
#  'combine',
#  'come',
#  'comfortable',
#  'coming',
#  'comment',
#  'commercial',
#  'commitment',
#  'common',
#  'communicate',
#  'communication',
#  'comp',
#  'companion',
#  'company',
#  'compared',
#  'compassion',
#  'compensate',
#  'compensated',
#  'compensation',
#  'competitor',
#  'complain',
#  'complaint',
#  'complete',
#  'completely',
#  'compliment',
#  'complimentary',
#  'computer',
#  'con',
#  'concern',
#  'concerned',
#  'concourse',
#  'condition',
#  'conf',
#  'conference',
#  'confident',
#  'confirm',
#  'confirmation',
#  'confirmed',
#  'confirming',
#  'confused',
#  'confusing',
#  'confusion',
#  'congrats',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'connector',
#  'consecutive',
#  'consider',
#  'consideration',
#  'considering',
#  'consistent',
#  'consistently',
#  'constant',
#  'constantly',
#  'cont',
#  'contact',
#  'contacted',
#  'contacting',
#  'content',
#  'contest',
#  'continental',
#  'contingency',
#  'continually',
#  'continue',
#  'continued',
#  'continues',
#  'continuing',
#  'continuous',
#  'contract',
#  'control',
#  'controller',
#  'convenient',
#  'conversation',
#  'conveyer',
#  'cool',
#  'coordinate',
#  'copilot',
#  'copy',
#  'corevalues',
#  'corner',
#  'corp',
#  'corporate',
#  'corporation',
#  'correct',
#  'corrected',
#  'correctly',
#  'cost',
#  'costa',
#  'costing',
#  'costumer',
#  'cot',
#  'could',
#  'couldnt',
#  'count',
#  'counter',
#  'counting',
#  'country',
#  'couple',
#  'coupon',
#  'courier',
#  'course',
#  'court',
#  'courteous',
#  'courtesy',
#  'cousin',
#  'cover',
#  'covered',
#  'covering',
#  'cowboycerrone',
#  'coworker',
#  'cp',
#  'cracker',
#  'cranky',
#  'crap',
#  'crappy',
#  'crash',
#  'crashed',
#  'crashing',
#  'crazy',
#  'created',
#  'credit',
#  'credited',
#  'crew',
#  'crisis',
#  'cross',
#  'crossed',
#  'crowd',
#  'cry',
#  'cs',
#  'csr',
#  'ctl',
#  'cuba',
#  'culture',
#  'cun',
#  'cup',
#  'curious',
#  'current',
#  'currently',
#  'cushion',
#  'cust',
#  'custom',
#  'customer',
#  'customers',
#  'customerservice',
#  'customerservicefail',
#  'custserv',
#  'cut',
#  'cute',
#  'cutting',
#  'cuz',
#  'cvg',
#  'cx',
#  'cxl',
#  'dad',
#  'daily',
#  'dakota',
#  'dal',
#  'dale',
#  'dallas',
#  'dallas_news',
#  'dallaslovefield',
#  'damage',
#  'damn',
#  'dance',
#  'dang',
#  'danger',
#  'dare',
#  'dark',
#  'data',
#  'date',
#  'dates',
#  'daughter',
#  'david',
#  'day',
#  'days',
#  'daytona',
#  'dbcvepn5qc',
#  'dc',
#  'dca',
#  'de',
#  'dead',
#  'deadhead',
#  'deaf',
#  'deal',
#  'dealing',
#  'deals',
#  'dear',
#  'death',
#  'debacle',
#  'debating',
#  'december',
#  'decent',
#  'decide',
#  'decided',
#  'decision',
#  'deck',
#  'deedee',
#  'deep',
#  'define',
#  'defines',
#  'definitely',
#  'definition',
#  'deflator',
#  ...]

# %%
# Applying SVM classifier on data
svc = SVC()
svc.fit(x_train1_features, y_train1)
svc.score(x_train2_features, y_train2)
# Out:
# 0.7635701275045538

# %%
# Applying Multinomial Naive Bayes classifier on data
nb = MultinomialNB()
nb.fit(x_train1_features, y_train1)
nb.score(x_train2_features, y_train2)
# Out:
# 0.7595628415300546

# %%
# Applying Random Forest classifier on data
rf = RandomForestClassifier()
rf.fit(x_train1_features, y_train1)
rf.score(x_train2_features, y_train2)
# Out:
# 0.7442622950819672

# %%
# Applying Logistic Regression classifier on data
lr = LogisticRegression(max_iter=200)
lr.fit(x_train1_features, y_train1)
lr.score(x_train2_features, y_train2)
# Out:
# 0.7777777777777778

# %%
# Applying Count Vectorizer on test data
count_vec = CountVectorizer(max_features=4000)
x_train_features = count_vec.fit_transform(train)
x_test_features = count_vec.transform(test_data)

# %%
svc = SVC()
svc.fit(x_train_features, train_output)
y_pred = svc.predict(x_test_features)

# %%
lr = LogisticRegression(max_iter=250)
lr.fit(x_train_features, train_output)
y_pred = lr.predict(x_test_features)

# %%
len(y_pred)
# Out:
# 3660

# %%
y_pred
# Out:
# array(['negative', 'negative', 'negative', ..., 'negative', 'positive',
#        'neutral'], dtype=object)

# %%
np.savetxt("Predictions-1.csv", y_pred, fmt='%s', delimiter=',')

# %% [markdown]
# # Using Neural Network

# %%
# Importing Libraries
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# %%
# Converting the data into labels
label = LabelEncoder()
y_train = label.fit_transform(train_output)

# %%
y_train.shape
# Out:
# (10980,)

# %%
x_train_features.shape
# Out:
# (10980, 4000)

# %%
# Encoding the data into categorical form
y_encoded = to_categorical(np.array(y_train))

# %%
# Adding hidden and output layers to the model
model = Sequential()
model.add(Dense(units=3000, activation='relu', input_dim=4000))
model.add(Dense(units=2000, activation='relu'))
model.add(Dense(units=1000, activation='relu'))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
# Specifying and compiling the loss function and optimizer
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train_features, y_encoded, epochs=10, batch_size=250)
# Out:
# Epoch 1/10
# 10980/10980 [==============================] - 17s 2ms/step - loss: 0.6693 - accuracy: 0.7160
# Epoch 2/10
# 10980/10980 [==============================] - 19s 2ms/step - loss: 0.2911 - accuracy: 0.8963
# Epoch 3/10
# 10980/10980 [==============================] - 20s 2ms/step - loss: 0.1080 - accuracy: 0.9639
# Epoch 4/10
# 10980/10980 [==============================] - 21s 2ms/step - loss: 0.0514 - accuracy: 0.9842
# Epoch 5/10
# 10980/10980 [==============================] - 24s 2ms/step - loss: 0.0349 - accuracy: 0.9889
# Epoch 6/10
# 10980/10980 [==============================] - 21s 2ms/step - loss: 0.0283 - accuracy: 0.9900
# Epoch 7/10
# 10980/10980 [==============================] - 17s 2ms/step - loss: 0.0223 - accuracy: 0.9915
# Epoch 8/10
# 10980/10980 [==============================] - 17s 2ms/step - loss: 0.0194 - accuracy: 0.9923
# Epoch 9/10
# 10980/10980 [==============================] - 17s 2ms/step - loss: 0.0187 - accuracy: 0.9922
# Epoch 10/10
# 10980/10980 [==============================] - 17s 2ms/step - loss: 0.0170 - accuracy: 0.9927

# %%
# Predicting the values for test data
predictions = model.predict(x_test_features)

# %%
# Picking only the max value for each datarow
predict = tf.argmax(predictions,1)

# %%
sess = tf.Session()
arr = np.array(sess.run(predict))

# %%
arr
# Out:
# array([0, 0, 0, ..., 0, 2, 1], dtype=int64)

# %%
# Converting the data into original categories
final = []
for i in arr:
    if i == 0:
        final.append('negative')
    elif i==1:
        final.append('neutral')
    else:
        final.append('positive')

# %%
final
# Out:
# ['negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  ...]

# %%
np.savetxt("PredictionsNN.csv", final, fmt='%s', delimiter=',')
